# %% [markdown]
# # import libararies
# * seaborn automatically install these libararies
# * matplotlib*
# * Numpy*
# * Scipy*
# * pandas*
# * matplotlib*

# %%
# import Libararies
import seaborn as sns
import matplotlib.pyplot as plt

#  load Data set
flower1= sns.load_dataset("iris")
flower1

# Draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width" , data=flower1)
plt.show()

# %% [markdown]
# # adding titles

# %%
# import Libararies
import seaborn as sns
import matplotlib.pyplot as plt

#  load Data set
flower1= sns.load_dataset("iris")
flower1

# Draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width" , data=flower1)
plt.title("flowers Plot")
plt.show()

# %% [markdown]
#  ## Adding Limits

# %%
# import Libararies
import seaborn as sns
import matplotlib.pyplot as plt

#  load Data set
flower1= sns.load_dataset("iris")
flower1

# Draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width" , data=flower1)
plt.title("flowers Plot")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
#  ## Set Styles
# . Seaborn Styles
# .  Seaborn includes 5 built-in styles that you can apply using sns.set_style():
#
# * darkgrid (default)
# * whitegrid
# * dark
# * white
# * ticks

# %%
# import Libararies
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style(style=None, rc=None)

#  load Data set
flower1= sns.load_dataset("iris")
flower1

# Draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width" , data=flower1)
plt.title("flowers Plot")
sns.set_style("dark")


plt.show()

# %%
# Import Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_style("whitegrid")  

# Load dataset
flower1 = sns.load_dataset("iris")

# Draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=flower1)

# Add title
plt.title("Flowers Plot")

# Show the plot
plt.show()

# %% [markdown]
# ## Change size of figure

# %%
# import Libararies
import seaborn as sns
import matplotlib.pyplot as plt

#  load Data set
flower1= sns.load_dataset("iris")
# Change figure
plt.figure( figsize=(4,2))

# Draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width" , data=flower1)
plt.title("flowers Plot")



plt.show()
